# %% [markdown]
# a link to the demo [demo.ipynb](demo.ipynb) so we can wiki the things
# what about [demo.html](demo.html)?
# if this is html then we'd need something like [../notebooks/index.html?path=demo.ipynb](../notebooks/index.html?path=demo.ipynb)
