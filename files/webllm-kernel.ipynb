# %% [markdown]
# ## Using the `WebLLM Chat` kernel to run built-in-ai LLMs as JupyterLite kernels
#
# The `WebLLM Chat` kernel is derived from a JupyterLite kernel implemented by [Aleksandar Sekulovski](https://www.linkedin.com/in/aleksandar-s-486829128/) at https://github.com/aleks-s10/agent-client-kernel/tree/main/lite-kernel.  This version currently lives at https://github.com/fovi-llc/wiki3-ai-site/tree/main/lite-kernel with Python installer by [Jim White](https://www.linkedin.com/in/jamespaulwhite/) and Copilot.  It will be moving to its own repo RSN.
#
# It is a TS/JS kernel that wraps `@built-in-ai/web-llm` from https://github.com/jakobhoeg/built-in-ai which is an [AI SDK model provider](https://ai-sdk.dev/) for open-source models (using WebLLM) running directly in the browser by [Jakob Hoeg Mørk](https://www.linkedin.com/in/jakob-hoeg-moerk/).
#
# ### &#128679; Under Construction &#128679; ###
# Watch this space for a kernel using `@built-in-ai/core` which wraps the Chrome/Edge built-in AI Prompt API (https://developer.chrome.com/docs/ai/built-in).
#
# This version is a PoC towards a Zed Agent Client Protocol (ACP) kernel which not only runs local-first LLMs but also agents (including coding agents).
#
# Example using the default, a "small" LLM: [SmolLM2-360M-Instruct-q4f16_1-MLC](https://huggingface.co/mlc-ai/SmolLM2-360M-Instruct-q4f16_1-MLC) which is 360M parameters quantized to 4bit and is 130MB.

# %%
how sweet would a rose smell by another name?
# Out:
# Sure, I can certainly help with that. 'Rose'?  A rose fragrance encounters!

# %% [markdown]
# Switched to [gemma-2-2b-it-q4f16_1-MLC](https://huggingface.co/mlc-ai/gemma-2-2b-it-q4f16_1-MLC).  This takes a while to download and run.  Watch the developer console and/or network tabs to track progress.

# %%
how do i build a skyscraper of straw?
# Out:
# Building a skyscraper out of straw is a fun and challenging idea! While it's not exactly practical for a real-world skyscraper, let's explore the concept and the challenges involved:
#
# **Understanding the Challenges**
#
# * **Strength and Stability:** Straw is generally flexible and not very strong. It's not a good choice for a skyscraper's structural support. Straw bales are often used for temporary structures or agricultural purposes, but not for permanent, high-rise buildings.
# * **Weight and Density:** Straw bales are relatively lightweight but their density is low. To create a stable structure that can withstand wind and gravity, you'd need to arrange them in a very specific and dense manner.
# * **Fire Safety:** Straw is a flammable material.  This is a major safety concern and would require extensive fireproofing measures.
# ...
