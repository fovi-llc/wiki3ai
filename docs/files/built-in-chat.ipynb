# %% [markdown]
# # Chrome AI Built-in Prompt API Demo
#
# This notebook demonstrates using Chrome's built-in AI (Gemini Nano) with the Prompt API [https://developer.chrome.com/docs/ai/prompt-api](https://developer.chrome.com/docs/ai/prompt-api).
#
# **Requirements:**
# - Chrome browser version 128+
# - Enable experimental flags:
#   - [chrome://flags/#prompt-api-for-gemini-nano](chrome://flags/#prompt-api-for-gemini-nano)
#   - [chrome://flags/#optimization-guide-on-device-model](chrome://flags/#optimization-guide-on-device-model)
# - [chrome://restart](chrome://restart)
# - First use requires downloading the Gemini Nano model
#
# - Open JupyterLite and create a notebook selecting the "Built-in AI Chat" kernel.
#
# This is a sample chat using the built-in-chat JupyterLite kernel for @built-in-ai/core which provides the Built In AI Prompt API

# %%
Explain the Pythagorean Theorem in three levels of expertise.
# Out:
# Okay, let's break down the Pythagorean Theorem into three levels of understanding: basic, intermediate, and advanced.
#
# ---
#
# ## Level 1: Basic - The Core Concept (Good for elementary school students or beginners)
#
# **What it is:**  The Pythagorean Theorem describes a specific relationship between the sides of a **right triangle**. A right triangle is a triangle with one angle that measures exactly 90 degrees (a "right angle").
#
# **The Theorem:**  The squared length of the longest side (called the **hypotenuse**) is equal to the sum of the squared lengths of the other two sides (called **legs**).
#
# **Formula:**  a² + b² = c²
#
# *   **a** and **b** are the lengths of the two shorter sides (legs).
# *   **c** is the length of the longest side (hypotenuse).
#
# **What does it mean?** Imagine you built a square on each side of the right triangle. The area of the square built on the hypotenuse is equal to the combined areas of the squares built on the other two sides.
#
# **Example:** If one leg is 3 units long (a=3) and the other leg is 4 units long (b=4), then:
# 3² + 4² = c²
# 9 + 16 = c²
# 25 = c²
# c = √25 = 5
#
# So the hypotenuse is 5 units long.
#
#
#
# ---
#
# ## Level 2: Intermediate - Understanding and Application (Good for middle school students or those needing a deeper grasp)
#
# **Building on the Basics:**  This level goes beyond simply memorizing the formula.  It involves understanding *why* the theorem works and how it can be applied to solve real-world problems.
#
# **Key Concepts:**
#
# *   **Right Triangles are Special:**  The Pythagorean Theorem *only* applies to right triangles. If you're not sure if you're dealing with a right triangle, you need to check for a 90-degree angle.
# *   **Hypotenuse is Always Longest:** The hypotenuse *must* be the longest side.  If you're given two sides and need to find the third, you need to identify the hypotenuse first.
# *   **Real-World Applications:**  The Theorem is used in many practical situations, such as:
#     *   Calculating distances.
#     *   Constructing buildings (making sure corners are square).
#     *   Navigation.
#     *   Engineering.
#
#
#
# **Problem-Solving:**  You can use the theorem to solve for any missing side of a right triangle *if you know the lengths of the other two sides*.
#
# **More Complex Scenarios:**
#
# *   **Word Problems:** You need to translate the word problem into a geometric setup. This involves identifying right triangles and labeling the sides correctly.
# *   **Finding Missing Sides:**  You can solve for *a*, *b*, or *c* depending on what you're given.
# *   **Checking Solutions:**  After solving, you should always plug your answer back into the Pythagorean Theorem to ensure your solution is correct.
#
#
#
# **Example:** A ladder is leaning against a wall. The base of the ladder is 6 feet from the wall, and the ladder reaches a height of 8 feet on the wall. How long is the ladder?
#
# *   This is a right triangle.  The wall, the ground, and the ladder form the sides.
# *   The wall is one leg (8 feet).
# *   The ground is another leg (6 feet).
# *   The ladder is the hypotenuse (we need to find its length).
#
# Using a² + b² = c²:
# 6² + 8² = c²
# 36 + 64 = c²
# 100 = c²
# c = √100 = 10
#
# The ladder is 10 feet long.
#
#
#
#
# ---
#
# ## Level 3: Advanced - Deeper Understanding & Extensions (Good for high school or those interested in advanced mathematics)
#
# **Beyond the Formula:** This level explores the theorem's mathematical properties, its connection to other concepts, and its applications in more sophisticated areas.
#
# **Key Concepts:**
#
# *   **Pythagorean Triples:**  These are sets of three positive integers (a, b, c) that satisfy the Pythagorean Theorem (e.g., 3, 4, 5; 5, 12, 13).  Understanding Pythagorean triples allows you to quickly recognize right triangles and find their hypotenuses. You can generate infinitely many triples using formulas.
# *   **Proofs of the Theorem:** Exploring the different geometric proofs (e.g., using area calculations, using transformations) provides a deeper appreciation of the theorem's validity.  There are many different proofs, showcasing various mathematical principles.
# *   **Trigonometry Connection:**  The Pythagorean Theorem is fundamental to trigonometry (sine, cosine, tangent).  The ratios in a right triangle are directly related to the theorem.
# *   **Generalizations:** The Pythagorean Theorem can be generalized to higher dimensions (e.g., in 3D space). The distance formula in 3D is an extension of the Pythagorean Theorem.
# *   **Geometric Identities:**  The Pythagorean Theorem is linked to other important mathematical identities.
#
# **Advanced Problem-Solving:**
#
# *   **Complex Geometric Constructions:** Applying the Theorem in more intricate constructions (e.g., creating equilateral triangles with specific sides).
# *    **Using the Theorem in Coordinate Geometry**:  The theorem is used to calculate distances between points on a coordinate plane.
# *  **Proofs involving the theorem**: Demonstrating a thorough understanding by constructing rigorous mathematical proofs.
#
#
#
# **Example:** Prove the Pythagorean Theorem using area calculations. (You would need to present a rigorous mathematical argument, often involving manipulating areas of squares).
#
#
#
# **In summary:**  The Pythagorean Theorem is a cornerstone of geometry. While the basic version is easily understood, its deeper implications and applications provide a rich and fascinating area of study.
